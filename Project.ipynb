# %% [markdown]
#  # **Project Name**    - **CREDIT CARD FRAUD DETECTION**

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Name - SHEIKH MOSTAQUL ARIF**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Mostaqul143

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report, confusion_matrix
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

df=pd.read_csv('CreditCard.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

df.head(10)
# Out:
#    Time    V1    V2    V3    V4    V5    V6    V7    V8    V9  ...   V21  \
# 0  0.00 -1.36 -0.07  2.54  1.38 -0.34  0.46  0.24  0.10  0.36  ... -0.02
# 1  0.00  1.19  0.27  0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ... -0.23
# 2  1.00 -1.36 -1.34  1.77  0.38 -0.50  1.80  0.79  0.25 -1.51  ...  0.25
# 3  1.00 -0.97 -0.19  1.79 -0.86 -0.01  1.25  0.24  0.38 -1.39  ... -0.11
# 4  2.00 -1.16  0.88  1.55  0.40 -0.41  0.10  0.59 -0.27  0.82  ... -0.01
# 5  2.00 -0.43  0.96  1.14 -0.17  0.42 -0.03  0.48  0.26 -0.57  ... -0.21
# 6  4.00  1.23  0.14  0.05  1.20  0.19  0.27 -0.01  0.08  0.46  ... -0.17
# 7  7.00 -0.64  1.42  1.07 -0.49  0.95  0.43  1.12 -3.81  0.62  ...  1.94
# 8  7.00 -0.89  0.29 -0.11 -0.27  2.67  3.72  0.37  0.85 -0.39  ... -0.07
# 9  9.00 -0.34  1.12  1.04 -0.22  0.50 -0.25  0.65  0.07 -0.74  ... -0.25
#
#     V22   V23   V24   V25   V26   V27   V28  Amount  Class
# 0  0.28 -0.11  0.07  0.13 -0.19  0.13 -0.02  149.62   0.00
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

print(f"Number Of Rows {df.shape[0]}")
print(f"Number Of Columns {df.shape[1]}")
# Out:
# Number Of Rows 52550
# Number Of Columns 31

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52550 entries, 0 to 52549
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    52550 non-null  float64
#  1   V1      52550 non-null  float64
#  2   V2      52550 non-null  float64
#  3   V3      52550 non-null  float64
#  4   V4      52550 non-null  float64
#  5   V5      52550 non-null  float64
#  6   V6      52550 non-null  float64
#  7   V7      52550 non-null  float64
#  8   V8      52550 non-null  float64
#  9   V9      52550 non-null  float64
#  10  V10     52550 non-null  float64
#  11  V11     52550 non-null  float64
#  12  V12     52550 non-null  float64
#  13  V13     52550 non-null  float64
#  14  V14     52550 non-null  float64
#  15  V15     52550 non-null  float64
#  16  V16     52550 non-null  float64
#  17  V17     52550 non-null  float64
#  18  V18     52550 non-null  float64
#  19  V19     52550 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

num_duplicates = df.duplicated().sum()
print(f"Number of Duplicate Values: {num_duplicates}")
# Out:
# Number of Duplicate Values: 232

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

num_missing = df.isnull().sum()
print("Number of Missing Values:\n", num_missing)
# Out:
# Number of Missing Values:
#  Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Visualizing the missing values


sns.heatmap(df.isnull(), cbar=False)
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **There are  52550 Number of  Rows and 31 Numbers of Columns Present in my dataset.**
#
# **There are 31 Numerical Columns and 0 Categorical Columns Present in my Dataset**
#
# **There are No Missing Values in my Dataset.**
#
# **There are 232 Number Of Duplicate Values Present in my  Dataset.**

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
# Dataset Describe

df.describe(include='all').transpose()
# Out:
#           count     mean      std    min      25%      50%      75%      max
# Time   52550.00 29698.24 13246.21   0.00 23069.25 33979.50 39824.00 45522.00
# V1     52550.00    -0.24     1.88 -56.41    -0.99    -0.25     1.15     1.96
# V2     52550.00     0.00     1.64 -72.72    -0.57     0.08     0.73    18.18
# V3     52550.00     0.69     1.49 -32.97     0.21     0.79     1.43     4.10
# V4     52550.00     0.18     1.40  -5.17    -0.72     0.19     1.06    16.49
# V5     52550.00    -0.26     1.41 -42.15    -0.87    -0.29     0.28    34.80
# V6     52550.00     0.10     1.31 -26.16    -0.63    -0.15     0.50    22.53
# V7     52550.00    -0.12     1.27 -26.55    -0.61    -0.08     0.42    36.68
# V8     52550.00     0.05     1.22 -41.48    -0.15     0.06     0.33    20.01
# V9     52550.00     0.10     1.20  -9.28    -0.63    -0.01     0.79    10.39
# V10    52550.00    -0.05     1.13 -18.27    -0.53    -0.11     0.42    13.20
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Time:** The time elapsed in seconds between this transaction and the first transaction in the dataset.
#
# **V1 to V28:** These columns contain numerical features resulting from a PCA transformation. The exact meaning of these features may not be clear due to the PCA transformation, but they are used to protect the privacy of credit cardholders while providing important information for fraud detection.
#
# **Amount:** The transaction amount.
#
# **Class:** This column contains binary values (0 or 1) that indicate whether a transaction is fraudulent (1) or not (0). It's the target variable for your credit card fraud detection task.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),"." )
# Out:
# No. of unique values in  Time is 26215 .
# No. of unique values in  V1 is 51396 .
# No. of unique values in  V2 is 51396 .
# No. of unique values in  V3 is 51396 .
# No. of unique values in  V4 is 51396 .
# No. of unique values in  V5 is 51396 .
# No. of unique values in  V6 is 51395 .
# No. of unique values in  V7 is 51394 .
# No. of unique values in  V8 is 51395 .
# No. of unique values in  V9 is 51396 .
# No. of unique values in  V10 is 51396 .
# No. of unique values in  V11 is 51396 .
# No. of unique values in  V12 is 51395 .
# No. of unique values in  V13 is 51396 .
# No. of unique values in  V14 is 51396 .
# No. of unique values in  V15 is 51396 .
# No. of unique values in  V16 is 51395 .
# No. of unique values in  V17 is 51395 .
# No. of unique values in  V18 is 51396 .
# No. of unique values in  V19 is 51396 .
# No. of unique values in  V20 is 51395 .
# No. of unique values in  V21 is 51396 .
# No. of unique values in  V22 is 51395 .
# No. of unique values in  V23 is 51394 .
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.


# Remove duplicate rows
""
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# *  **I Removed The Duplicate Rows From My Dataset**

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code


# Set the style for seaborn plots
sns.set(style="whitegrid")

# countplot to visualize the distribution of fraud (Class 1) vs. non-fraud (Class 0) transactions
plt.figure(figsize=(8, 6))
sns.countplot(x='Class', data=df)
plt.title("Distribution of Classes (Fraud vs. Non-Fraud)")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot chart was chosen to visualize the distribution of fraud (Class 1) vs. non-fraud (Class 0) transactions because it effectively illustrates the class imbalance in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  **The countplot shows that the dataset is highly imbalanced, with a significantly higher number of non-fraud transactions (Class 0) compared to fraud transactions (Class 1).**

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# Plot histograms of transaction amounts for fraud and non-fraud transactions
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Class'] == 0]['Amount'], bins=50, label='Non-Fraud', kde=True)
sns.histplot(df[df['Class'] == 1]['Amount'], bins=50, label='Fraud', kde=True)
plt.title("Distribution of Transaction Amounts")
plt.xlabel("Transaction Amount")
plt.ylabel("Count")
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histograms are often used to visualize the distribution of a single variable, making it easy to understand how data is spread across different values. In the context of the provided dataset, histograms were chosen to visualize the distribution of transaction amounts for fraud and non-fraud transactions because they effectively show the spread of amounts and can highlight any differences between the two classes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   **The histogram of transaction amounts for fraud and non-fraud transactions shows differences in the distribution of transaction amounts between the two classes.**

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# Explore the time distribution of transactions
plt.figure(figsize=(10, 6))
sns.histplot(df['Time'], bins=100, kde=True)
plt.title("Distribution of Transaction Time")
plt.xlabel("Time (seconds)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  **The distribution of transaction times may reveal patterns in the data, such as potential time-based fraud trends.**

# %% [markdown]
# #### Chart - 4 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Set title
plt.title('Correlation Heatmap')

# Display the plot
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **The correlation matrix heatmap can help identify potential relationships between numerical features. Variables with high absolute correlation values may be relevant for modeling.**

# %% [markdown]
# #### Chart - 5 - Pair Plot

# %%
# Pair Plot visualization code

sns.pairplot(df[['V1', 'V2', 'V3', 'V4', 'V5', 'Class']], hue='Class', markers=['o', 's'], diag_kind='kde')
plt.title("Pairplot of Selected Features")
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **The pairplot allows you to visualize the distribution and relationships between selected features, especially between fraud and non-fraud transactions.**

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
